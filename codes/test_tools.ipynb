# %% [markdown]
# Test: codes.person_detection

# %%
import cv2 
import numpy as np 
import matplotlib.pyplot as plt 
from person_detection import person_detection_body, person_detection_face, person_detection_hog

# %%
image_dir = '../data/Lenna.png'
img = cv2.imread(image_dir)

plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.title("original image")
plt.show()

# %%
detection_result, img_result = person_detection_face(img, img_show=True)
print(detection_result)
# Out:
# 1

# %%
image_dir = '../data/test-image01.jpg'
img = cv2.imread(image_dir)

plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.title("original image")
plt.show()

# %%
detection_result, img_result = person_detection_face(img, img_show=True)
print(detection_result)
# Out:
# 16

# %%
detection_result, img_result = person_detection_body(img, img_show=True)
print(detection_result)
# Out:
# 13

# %%
detection_result, img_result = person_detection_hog(img, img_show=True)
print(detection_result)
# Out:
# 5

# %%
image_dir = '../data/test-image02.jpeg'
img = cv2.imread(image_dir)

plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.title("original image")
plt.show()

# %%
detection_result, img_result = person_detection_face(img, img_show=True)
print(detection_result)
# Out:
# 1
